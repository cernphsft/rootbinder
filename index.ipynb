# %% [markdown]
# ![title](images/banner.png)
#     <p style="margin-right:5%; margin-left:5%; font-size:22px; font-weight: 200; line-height: 1.2em">
# [ROOT](root.cern.ch) is a framework for data processing, born at [CERN](www.cern.ch), at the heart of the research on high-energy physics. Every day, thousands of physicists use ROOT applications to analyze petabytes of data or to perform simulations.
# <table style="border-style: hidden; border-collapse: collapse;">
# <tr>
#     <td style="border-style: hidden;">
#         <p style="font-size:28px; font-weight: 200; line-height: 1.2em">
#         <b>Try a ROOTbook now: <br/> choose your favourite language!</b>
#         <p>
#     </td>
#     <td style="border-style: hidden;">
#         <br>
#         <a href="notebooks/PyROOT_Example.ipynb">
#             <img src="images/pythonLogo.png" alt="Python Logo" style="width: 147px;"/>
#         </a>
#     </td>
#     <td style="border-style: hidden;">
#         <a href="notebooks/ROOT_Example.ipynb">
#         <img src="images/cppLogo_v2.png" alt="C++ Logo" style="width: 147px;"/>
#         </a>
#     </td>
#     <!--
#     <td>
#     <p style="margin-right:5%; margin-left:5%; font-size:18px; font-weight: 200; line-height: 1.2em">
# [ROOT](root.cern.ch) is a framework for data processing, born at [CERN](www.cern.ch), at the heart of the research on high-energy physics. Every day, thousands of physicists use ROOT applications to analyze petabytes of data or to perform simulations.
# <br>
# <br>
# ** Click on one of the icons to try a ROOTBook now! **
# </p>
#     </td>
#     -->
# </tr>
# </table>
#
# <!--
# <a data-content="Image" href="notebooks/PyROOT_Example.ipynb" class="test"><img class='thumbnail'style='float: left; width: 147; margin-right: 15px; margin-top: 15px; -web-kit-shadow: None !important; box-shadow: None !important; margin-bottom: 0px;' src="images/pythonLogo.png"></a>
#
# <a data-content="Image" href="notebooks/PyROOT_Example.ipynb" class="test"><img class='thumbnail'style='float: left; width: 147; margin-right: 15px; margin-top: 15px; -web-kit-shadow: None !important; box-shadow: None !important; margin-bottom: 0px;' src="images/cppLogo_v2.png"></a>
# -->

# %% [markdown]
# # More ROOTBooks!
# <hr style="border-top-width: 4px; border-top-color: #34609b;">
#
# <table style="border-style: hidden; border-collapse: collapse;">
# <tr>
#   <td style="border-style: hidden;">
#   <a data-content="Image" href="notebooks/Slits.ipynb" class="test"><img class='thumbnail'style='float: left; height: 200px; margin-right: 15px; margin-top: 15px; -web-kit-shadow: None !important; box-shadow: None !important; margin-bottom: 0px;' src="images/Slits.png"></a>
#   </td>
#   <td style="border-style: hidden;">
#   <a data-content="Image" href="notebooks/HiggsFit.ipynb" class="test"><img class='thumbnail'style='float: left; height: 200px; margin-right: 15px; margin-top: 15px; -web-kit-shadow: None !important; box-shadow: None !important; margin-bottom: 0px;' src="images/higgsOriz.png"></a>
#   </td>
#   <!--
#   <td style="border-style: hidden;">
#   <a data-content="Image" href="notebooks/Slits.ipynb" class="test"><img class='thumbnail'style='float: left; width: 150px; margin-right: 15px; margin-top: 15px; -web-kit-shadow: None !important; box-shadow: None !important; margin-bottom: 0px;' src="images/sam.png"></a>
#   </td>
#   -->
# </tr>
#
# <tr>
#   <td style="border-style: hidden;">
#   <p style="font-size:22px; font-weight: 200; line-height: 1.2em">Education: Intereference</p>
#   </td>
#   <td style="border-style: hidden;">
#   <p style="font-size:22px; font-weight: 200; line-height: 1.2em">Science: Higgs</p>
#   </td>
#   <!--
#   <td style="border-style: hidden;">
#   <p style="font-size:22px; font-weight: 200; line-height: 1.2em">Technology: MVA</p>
#   </td>
#   -->
# </tr>
# </table>

# %% [markdown]
# # C++ Interactive shell
# <hr style="border-top-width: 4px; border-top-color: #34609b;">
# <p style="margin-right:10%; margin-left:5%; font-size:18px; font-weight: 200; line-height: 1.2em">
# Yes. ROOT features a full blown C++ interpreter built on top of [LLVM and Clang](http://clang.llvm.org/) libraries.
# </p>
# <a data-content="Image" href="notebooks/Interactive_C++_Shell.ipynb" class="test"><img class='thumbnail'style='float: left; width: 147; margin-right: 15px; margin-top: 15px; -web-kit-shadow: None !important; box-shadow: None !important; margin-bottom: 0px;' src="images/ROOTShell.png"></a>

# %% [markdown]
# View these notebooks on [GitHub](https://github.com/cernphsft?tab=repositories)
